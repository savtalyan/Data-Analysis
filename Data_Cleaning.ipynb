# %%
# In this example, we will clean up a dataset, and try to find out which movie genre was the most popular in different years
# Let's go ahead

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\User\Downloads\movies.csv")

# %%
df.shape
# Out:
# (9999, 9)

# %%
# Let's set max rows display amount to 100, so we will be able to scroll

pd.set_option('display.max_rows', 20)

# %%
df.head(10)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
# 5                          Outer Banks     (2020– )
# 6      The Last Letter from Your Lover       (2021)
# 7                               Dexter  (2006–2013)
# 8                    Never Have I Ever     (2020– )
# 9                         Virgin River     (2019– )
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
# 5          \nAction, Crime, Drama                 7.6
# ...

# %%
# as we can see the same situation with unclean data is everywhere in this dataset.
# let's begin to clean it up
# First of all, I would like to remove parantheses form YEAR column

# And I think it would be better, to split YEAR column into two columns, Starting_Year and Ending_Year. 

df['YEAR'] = df['YEAR'].str.strip('()')
df['Starting_Year'] = df['YEAR'].str[:4]
df['Ending_Year'] = df['YEAR'].str[-5:]

# We get the dashes in the end of some values in Ending_Year, so I decided to replace with empty string everything except numbers
df['Ending_Year'] = df['Ending_Year'].str.replace(r'\D','', regex=True)

# Now it looks good. Lets drop YEAR column and change the indexes of two new columns to bring them forward
df.drop('YEAR', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#                                 MOVIES  \
# 0                        Blood Red Sky
# 1  Masters of the Universe: Revelation
# 2                     The Walking Dead
# 3                       Rick and Morty
# 4                      Army of Thieves
# 5                          Outer Banks
# 6      The Last Letter from Your Lover
# 7                               Dexter
# 8                    Never Have I Ever
# 9                         Virgin River
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
# 5          \nAction, Crime, Drama                 7.6
# 6                \nDrama, Romance                 6.8
# 7         \nCrime, Drama, Mystery                 8.6
# ...

# %%
df.columns
# Out:
# Index(['MOVIES', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES', 'RunTime',
#        'Gross', 'Starting_Year', 'Ending_Year'],
#       dtype='object')

# %%
# Let's drop columns we are not gonna use
columns = ['ONE-LINE', 'RunTime', 'Gross', 'STARS']
df.drop(columns, axis =1)
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING    VOTES  \
# 0         \nAction, Horror, Thriller                 6.1   21,062
# 1     \nAnimation, Action, Adventure                 5.0   17,870
# 2          \nDrama, Horror, Thriller                 8.2  885,805
# 3     \nAnimation, Adventure, Comedy                 9.2  414,849
# 4            \nAction, Crime, Horror                 NaN      NaN
# ...

# %%
df.columns
# Out:
# Index(['MOVIES', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES', 'RunTime',
#        'Gross', 'Starting_Year', 'Ending_Year'],
#       dtype='object')

# %%
# I want to change the order of columns

new_order = ['MOVIES', 'Starting_Year', 'Ending_Year', 'GENRE', 'RATING', 'VOTES']
df = df[new_order]
df.head(5)
# Out:
#                                 MOVIES Starting_Year Ending_Year  \
# 0                        Blood Red Sky          2021        2021
# 1  Masters of the Universe: Revelation          2021         021
# 2                     The Walking Dead          2010        2022
# 3                       Rick and Morty          2013         013
# 4                      Army of Thieves          2021        2021
#
#                                         GENRE  RATING    VOTES
# 0      \nAction, Horror, Thriller                 6.1   21,062
# 1  \nAnimation, Action, Adventure                 5.0   17,870
# 2       \nDrama, Horror, Thriller                 8.2  885,805
# 3  \nAnimation, Adventure, Comedy                 9.2  414,849
# 4         \nAction, Crime, Horror                 NaN      NaN

# %%
# Now it looks better 
# Let's go ahead and remove new line characters from GENRE column

df['GENRE'] = df['GENRE'].str.replace('\n', '')
df.head(10)
# Out:
#                                 MOVIES Starting_Year Ending_Year  \
# 0                        Blood Red Sky          2021        2021
# 1  Masters of the Universe: Revelation          2021         021
# 2                     The Walking Dead          2010        2022
# 3                       Rick and Morty          2013         013
# 4                      Army of Thieves          2021        2021
# 5                          Outer Banks          2020         020
# 6      The Last Letter from Your Lover          2021        2021
# 7                               Dexter          2006        2013
# 8                    Never Have I Ever          2020         020
# 9                         Virgin River          2019         019
#
#                                       GENRE  RATING    VOTES
# 0      Action, Horror, Thriller                 6.1   21,062
# 1  Animation, Action, Adventure                 5.0   17,870
# 2       Drama, Horror, Thriller                 8.2  885,805
# ...

# %%
# Now it is almost ready for our calculations. 
# We just need to set all NaN values equal to 0

df.fillna(0, inplace=True)

# %%
df.head(10)
# Out:
#                                 MOVIES Starting_Year Ending_Year  \
# 0                        Blood Red Sky          2021        2021
# 1  Masters of the Universe: Revelation          2021         021
# 2                     The Walking Dead          2010        2022
# 3                       Rick and Morty          2013         013
# 4                      Army of Thieves          2021        2021
# 5                          Outer Banks          2020         020
# 6      The Last Letter from Your Lover          2021        2021
# 7                               Dexter          2006        2013
# 8                    Never Have I Ever          2020         020
# 9                         Virgin River          2019         019
#
#                                       GENRE  RATING    VOTES
# 0      Action, Horror, Thriller                 6.1   21,062
# 1  Animation, Action, Adventure                 5.0   17,870
# 2       Drama, Horror, Thriller                 8.2  885,805
# ...
